# %%
# All imports
import numpy as np
import pandas as pd

# %%
cars_per_cap = [809, 731, 588, 18, 200, 70, 45]
country = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
drives_right = [True, False, False, False, True, True, True]

# %%
data ={"cars_per_cap":cars_per_cap , "country":country , "drives_right" : drives_right}
data
print(type(data)) #dictionary
# Out:
# <class 'dict'>

# %%
cars_d = pd.DataFrame(data)
cars_d
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True

# %%
type(cars_d)
# Out:
# pandas.core.frame.DataFrame

# %%
cars_pf =pd.read_csv('cars.csv')
cars_pf
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %%
# Returns an array of headers

print(cars_df.columns)
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
cars_df = pd.read_csv('cars.csv', header=None)
cars_df
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
# Returns an array of headers

print(cars_df.columns)
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
# Rename Headers

cars_df.columns = ['country code', 'region', 'country', 'cars_per_cap', 'drive_right']
cars_df
# Out:
#   country code region        country  cars_per_cap  drive_right
# 0         USCA     US  United States         809.0        False
# 1        ASPAC    AUS      Australia         731.0         True
# 2        ASPAC    JAP          Japan         588.0         True
# 3        ASPAC     IN          India          18.0         True
# 4        ASPAC     RU         Russia         200.0        False
# 5        LATAM    MOR        Morocco          70.0        False
# 6          AFR     EG          Egypt          45.0        False
# 7          EUR    ENG        England           NaN         True

# %%
# Index is returned by
cars_df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
# Read file and set 1st column as index
cars_df = pd.read_csv("cars.csv", header= None, index_col=0)

# set the column names
cars_df.columns = ['region', 'country', 'cars_per_cap', 'drive_right']
cars_df
# Out:
#       region        country  cars_per_cap  drive_right
# 0
# USCA      US  United States         809.0        False
# ASPAC    AUS      Australia         731.0         True
# ASPAC    JAP          Japan         588.0         True
# ASPAC     IN          India          18.0         True
# ASPAC     RU         Russia         200.0        False
# LATAM    MOR        Morocco          70.0        False
# AFR       EG          Egypt          45.0        False
# EUR      ENG        England           NaN         True

# %%
cars_df.columns
# Out:
# Index(['region', 'country', 'cars_per_cap', 'drive_right'], dtype='object')

# %%
cars_df.index
# Out:
# Index(['USCA', 'ASPAC', 'ASPAC', 'ASPAC', 'ASPAC', 'LATAM', 'AFR', 'EUR'], dtype='object', name=0)

# %%
cars_df.index.name='Country Code'
cars_df
# Out:
#              region        country  cars_per_cap  drive_right
# Country Code
# USCA             US  United States         809.0        False
# ASPAC           AUS      Australia         731.0         True
# ASPAC           JAP          Japan         588.0         True
# ASPAC            IN          India          18.0         True
# ASPAC            RU         Russia         200.0        False
# LATAM           MOR        Morocco          70.0        False
# AFR              EG          Egypt          45.0        False
# EUR             ENG        England           NaN         True

# %%
cars_df.index
# Out:
# Index(['USCA', 'ASPAC', 'ASPAC', 'ASPAC', 'ASPAC', 'LATAM', 'AFR', 'EUR'], dtype='object', name='Country Code')

# %%
#delete index name
cars_df.index.name=None
cars_df
# Out:
#       region        country  cars_per_cap  drive_right
# USCA      US  United States         809.0        False
# ASPAC    AUS      Australia         731.0         True
# ASPAC    JAP          Japan         588.0         True
# ASPAC     IN          India          18.0         True
# ASPAC     RU         Russia         200.0        False
# LATAM    MOR        Morocco          70.0        False
# AFR       EG          Egypt          45.0        False
# EUR      ENG        England           NaN         True

# %%
cars_df.index
# Out:
# Index(['USCA', 'ASPAC', 'ASPAC', 'ASPAC', 'ASPAC', 'LATAM', 'AFR', 'EUR'], dtype='object')

# %%
#set herarchical index
cars_dh = pd.read_csv('cars.csv',header=None)
cars_dh
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
# set the column names
cars_dh.columns = ['country_code','region','country','cars_per_cap','drives_right']
cars_dh
# Out:
#   country_code region        country  cars_per_cap  drives_right
# 0         USCA     US  United States         809.0         False
# 1        ASPAC    AUS      Australia         731.0          True
# 2        ASPAC    JAP          Japan         588.0          True
# 3        ASPAC     IN          India          18.0          True
# 4        ASPAC     RU         Russia         200.0         False
# 5        LATAM    MOR        Morocco          70.0         False
# 6          AFR     EG          Egypt          45.0         False
# 7          EUR    ENG        England           NaN          True

# %%
cars_dh.set_index(['region','country_code'] , inplace=True)
cars_dh
# Out:
#                            country  cars_per_cap  drives_right
# region country_code
# US     USCA          United States         809.0         False
# AUS    ASPAC             Australia         731.0          True
# JAP    ASPAC                 Japan         588.0          True
# IN     ASPAC                 India          18.0          True
# RU     ASPAC                Russia         200.0         False
# MOR    LATAM               Morocco          70.0         False
# EG     AFR                   Egypt          45.0         False
# ENG    EUR                 England           NaN          True

# %%
#set herarchical index
cars_dh = pd.read_csv('cars.csv',header=None)
# set the column names
cars_dh.columns = ['country_code','region','country','cars_per_cap','drives_right']
cars_dh.set_index(['region','country_code'] ,inplace=True)
cars_dh
# Out:
#                            country  cars_per_cap  drives_right
# region country_code
# US     USCA          United States         809.0         False
# AUS    ASPAC             Australia         731.0          True
# JAP    ASPAC                 Japan         588.0          True
# IN     ASPAC                 India          18.0          True
# RU     ASPAC                Russia         200.0         False
# MOR    LATAM               Morocco          70.0         False
# EG     AFR                   Egypt          45.0         False
# ENG    EUR                 England           NaN          True

# %%
cars_dh.index
# Out:
# MultiIndex([( 'US',  'USCA'),
#             ('AUS', 'ASPAC'),
#             ('JAP', 'ASPAC'),
#             ( 'IN', 'ASPAC'),
#             ( 'RU', 'ASPAC'),
#             ('MOR', 'LATAM'),
#             ( 'EG',   'AFR'),
#             ('ENG',   'EUR')],
#            names=['region', 'country_code'])

# %%
cars_dh.to_csv('cars_to_csv.csv')

# %%
cars_fromf = pd.read_csv('cars_to_csv.csv' , header=None)
cars_fromf.columns = ('AAA' , 'BBB' , 'CCC', 'DDD' , 'EEE')
cars_fromf.set_index(['AAA' , 'BBB' ],inplace=True)
cars_fromf
# Out:
#                                CCC           DDD           EEE
# AAA    BBB
# region country_code        country  cars_per_cap  drives_right
# US     USCA          United States         809.0         False
# AUS    ASPAC             Australia         731.0          True
# JAP    ASPAC                 Japan         588.0          True
# IN     ASPAC                 India          18.0          True
# RU     ASPAC                Russia         200.0         False
# MOR    LATAM               Morocco          70.0         False
# EG     AFR                   Egypt          45.0         False
# ENG    EUR                 England           NaN          True

# %%
marks = pd.read_csv('marks_2.csv',header=None,index_col=0)
marks.columns = (['Name','Subject','Maximum Marks','Marks Obtained','Percentage'])

marks.index.name='S.No.'
marks
# Out:
#           Name      Subject  Maximum Marks  Marks Obtained  Percentage
# S.No.
# 1       Akshay  Mathematics             50              40          80
# 2       Mahima      English             40              33          83
# 3        Vikas  Mathematics             50              42          84
# 4      Abhinav      English             40              31          78
# 5       Mahima      Science             50              40          80
# 6       Akshay      Science             50              49          98
# 7      Abhinav  Mathematics             50              47          94
# 8        Vikas      Science             50              40          80
# 9      Abhinav      Science             50              47          94
# 10       Vikas      English             40              39          98
# 11      Akshay      English             40              35          88
# 12      Mahima  Mathematics             50              43          86

# %%
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv',sep='|',header=None,index_col=0)
df.columns = (['Name','Subject','Maximum Marks','Marks Obtained','Percentage'])

df.index.name='S.No.'
df

print(df)
# Out:
#           Name      Subject  Maximum Marks  Marks Obtained  Percentage
# S.No.
# 1       Akshay  Mathematics             50              40          80
# 2       Mahima      English             40              33          83
# 3        Vikas  Mathematics             50              42          84
# 4      Abhinav      English             40              31          78
# 5       Mahima      Science             50              40          80
# 6       Akshay      Science             50              49          98
# 7      Abhinav  Mathematics             50              47          94
# 8        Vikas      Science             50              40          80
# 9      Abhinav      Science             50              47          94
# 10       Vikas      English             40              39          98
# 11      Akshay      English             40              35          88
# 12      Mahima  Mathematics             50              43          86

# %%
sales =pd.read_excel('sales.xlsx')
sales
# Out:
#           Market             Region  No_of_Orders    Profit      Sales
# 0         Africa     Western Africa           251 -12901.51   78476.06
# 1         Africa    Southern Africa            85  11768.58   51319.50
# 2         Africa       North Africa           182  21643.08   86698.89
# 3         Africa     Eastern Africa           110   8013.04   44182.60
# 4         Africa     Central Africa           103  15606.30   61689.99
# 5   Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6   Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7   Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8   Asia Pacific            Oceania           646  54734.02  408002.98
# 9   Asia Pacific       Eastern Asia           414  72805.10  315390.77
# 10  Asia Pacific       Central Asia            37  -2649.76    8190.74
# 11        Europe     Western Europe           964  82091.27  656637.14
# ...

# %%
sales =pd.read_excel('sales.xlsx'  , index_col=0)
sales
# Out:
#                          Region  No_of_Orders    Profit      Sales
# Market
# Africa           Western Africa           251 -12901.51   78476.06
# Africa          Southern Africa            85  11768.58   51319.50
# Africa             North Africa           182  21643.08   86698.89
# Africa           Eastern Africa           110   8013.04   44182.60
# Africa           Central Africa           103  15606.30   61689.99
# Asia Pacific       Western Asia           382 -16766.90  124312.24
# Asia Pacific      Southern Asia           469  67998.76  351806.60
# Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# Asia Pacific            Oceania           646  54734.02  408002.98
# Asia Pacific       Eastern Asia           414  72805.10  315390.77
# Asia Pacific       Central Asia            37  -2649.76    8190.74
# Europe           Western Europe           964  82091.27  656637.14
# Europe          Southern Europe           338  18911.49  215703.93
# ...

# %%
sales =pd.read_excel('sales.xlsx'  , index_col=[0,1])
sales
# Out:
#                                 No_of_Orders    Profit      Sales
# Market       Region
# Africa       Western Africa              251 -12901.51   78476.06
#              Southern Africa              85  11768.58   51319.50
#              North Africa                182  21643.08   86698.89
#              Eastern Africa              110   8013.04   44182.60
#              Central Africa              103  15606.30   61689.99
# Asia Pacific Western Asia                382 -16766.90  124312.24
#              Southern Asia               469  67998.76  351806.60
#              Southeastern Asia           533  20948.84  329751.38
#              Oceania                     646  54734.02  408002.98
#              Eastern Asia                414  72805.10  315390.77
#              Central Asia                 37  -2649.76    8190.74
# Europe       Western Europe              964  82091.27  656637.14
#              Southern Europe             338  18911.49  215703.93
# ...

# %%
rating = pd.read_csv('rating.csv')
rating
# Out:
#         ID Department     Office  Rating
# 0    U2F26    Finance  New Delhi     3.4
# 1    U2M61  Marketing  New Delhi     3.9
# 2    U1S15      Sales  New Delhi     2.8
# 3    U1H87         HR     Mumbai     2.1
# 4    U1S51      Sales  New Delhi     4.6
# ..     ...        ...        ...     ...
# 528  U3S44      Sales  New Delhi     4.8
# 529  U2M11  Marketing  Bangalore     2.5
# 530  U3F53    Finance  Bangalore     3.2
# 531  U3S46      Sales  Bangalore     2.9
# 532  U3S28      Sales  New Delhi     2.9
#
# [533 rows x 4 columns]

# %%
#Create a hierarchical index based on two columns: Office and Department
rating = pd.read_csv('rating.csv',index_col=[2,1])

rating.sort_index(True)
rating.tail(5)
# Out:
# C:\Users\tnaazsha\AppData\Local\Temp/ipykernel_15224/2661436703.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_index will be keyword-only
#   rating.sort_index(True)
#                          ID  Rating
# Office    Department
# New Delhi Sales       U3S44     4.8
# Bangalore Marketing   U2M11     2.5
#           Finance     U3F53     3.2
#           Sales       U3S46     2.9
# New Delhi Sales       U3S28     2.9

# %%
rating.tail(10)
# Out:
#                          ID  Rating
# Office    Department
# New Delhi Finance     U3F46     3.6
#           Marketing   U1M31     4.6
#           Sales       U1S25     3.4
# Mumbai    Sales       U2S35     4.9
# Bangalore Sales       U1S22     3.4
# New Delhi Sales       U3S44     4.8
# Bangalore Marketing   U2M11     2.5
#           Finance     U3F53     3.2
#           Sales       U3S46     2.9
# New Delhi Sales       U3S28     2.9

# %%
rating.describe()
# Out:
#            Rating
# count  524.000000
# mean     3.550191
# std      0.850430
# min      2.100000
# 25%      2.800000
# 50%      3.500000
# 75%      4.300000
# max      5.000000

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 533 entries, ('New Delhi', 'Finance') to ('New Delhi', 'Sales')
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      533 non-null    object
#  1   Rating  524 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 9.8+ KB

# %%
import matplotlib.pyplot as plt

# %%
sales.describe()
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 23 entries, ('Africa', 'Western Africa') to ('USCA', 'Canada')
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No_of_Orders  23 non-null     int64
#  1   Profit        23 non-null     float64
#  2   Sales         23 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.6+ KB

# %%
sales[["Sales","Profit"]].plot(kind="box", subplots=True)
plt.show()

# %%
sales["Sales"]
# Out:
# Market        Region
# Africa        Western Africa        78476.06
#               Southern Africa       51319.50
#               North Africa          86698.89
#               Eastern Africa        44182.60
#               Central Africa        61689.99
# Asia Pacific  Western Asia         124312.24
#               Southern Asia        351806.60
#               Southeastern Asia    329751.38
#               Oceania              408002.98
#               Eastern Asia         315390.77
#               Central Asia           8190.74
# Europe        Western Europe       656637.14
#               Southern Europe      215703.93
#               Northern Europe      252969.09
#               Eastern Europe       108258.93
# LATAM         South America        210710.49
#               Central America      461670.28
#               Caribbean            116333.05
# USCA          Western US           251991.83
#               Southern US          148771.91
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
print(df.describe())
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
print(df.columns)
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (517, 13)

# %%
sales = pd.read_excel("sales.xlsx" , index_col=1)
sales
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Western Africa           Africa           251 -12901.51   78476.06
# Southern Africa          Africa            85  11768.58   51319.50
# North Africa             Africa           182  21643.08   86698.89
# Eastern Africa           Africa           110   8013.04   44182.60
# Central Africa           Africa           103  15606.30   61689.99
# Western Asia       Asia Pacific           382 -16766.90  124312.24
# Southern Asia      Asia Pacific           469  67998.76  351806.60
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98
# Eastern Asia       Asia Pacific           414  72805.10  315390.77
# Central Asia       Asia Pacific            37  -2649.76    8190.74
# Western Europe           Europe           964  82091.27  656637.14
# Southern Europe          Europe           338  18911.49  215703.93
# ...

# %%
sales.Sales
# Out:
# Region
# Western Africa        78476.06
# Southern Africa       51319.50
# North Africa          86698.89
# Eastern Africa        44182.60
# Central Africa        61689.99
# Western Asia         124312.24
# Southern Asia        351806.60
# Southeastern Asia    329751.38
# Oceania              408002.98
# Eastern Asia         315390.77
# Central Asia           8190.74
# Western Europe       656637.14
# Southern Europe      215703.93
# Northern Europe      252969.09
# Eastern Europe       108258.93
# South America        210710.49
# Central America      461670.28
# Caribbean            116333.05
# Western US           251991.83
# Southern US          148771.91
# Eastern US           264973.98
# Central US           170416.31
# Canada                26298.81
# Name: Sales, dtype: float64

# %%
sales["Sales"]
# Out:
# Region
# Western Africa        78476.06
# Southern Africa       51319.50
# North Africa          86698.89
# Eastern Africa        44182.60
# Central Africa        61689.99
# Western Asia         124312.24
# Southern Asia        351806.60
# Southeastern Asia    329751.38
# Oceania              408002.98
# Eastern Asia         315390.77
# Central Asia           8190.74
# Western Europe       656637.14
# Southern Europe      215703.93
# Northern Europe      252969.09
# Eastern Europe       108258.93
# South America        210710.49
# Central America      461670.28
# Caribbean            116333.05
# Western US           251991.83
# Southern US          148771.91
# Eastern US           264973.98
# Central US           170416.31
# Canada                26298.81
# Name: Sales, dtype: float64

# %%
type(sales.Sales)
# Out:
# pandas.core.series.Series

# %%
type(sales["Sales"])
# Out:
# pandas.core.series.Series

# %%
sales.Profit #Can access columns other than IDs.
# Out:
# Region
# Western Africa      -12901.51
# Southern Africa      11768.58
# North Africa         21643.08
# Eastern Africa        8013.04
# Central Africa       15606.30
# Western Asia        -16766.90
# Southern Asia        67998.76
# Southeastern Asia    20948.84
# Oceania              54734.02
# Eastern Asia         72805.10
# Central Asia         -2649.76
# Western Europe       82091.27
# Southern Europe      18911.49
# Northern Europe      43237.44
# Eastern Europe       25050.69
# South America        12377.59
# Central America      74679.54
# Caribbean            13529.59
# Western US           44303.65
# Southern US          19991.83
# Eastern US           47462.04
# Central US           33697.43
# Canada                7246.62
# Name: Profit, dtype: float64

# %%
sales.iloc[10] #a particular row
# Out:
# Market          Asia Pacific
# No_of_Orders              37
# Profit              -2649.76
# Sales                8190.74
# Name: Central Asia, dtype: object

# %%
sales.iloc[10][0]
# Out:
# 37.0

# %%
sales.loc["Western Africa" , "Profit"]  #index particular row by index name and column
# Out:
# -12901.51

# %%
sales.loc["Central Asia","Profit"]
# Out:
# -2649.76

# %%
sales.iloc[6,3]
# Out:
# 351806.6

# %%
#Print out the columns 'month', 'day', 'temp', 'area' from the dataframe 'df'.
df_2 = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
df_2=df_2[["month" , "day" , "temp" , "area"]] #Type your code for selecting columns 'month', 'day' , 'temp' , 'area'
print(df_2.head(20))
# Out:
#    month  day  temp  area
# 0    mar  fri   8.2   0.0
# 1    oct  tue  18.0   0.0
# 2    oct  sat  14.6   0.0
# 3    mar  fri   8.3   0.0
# 4    mar  sun  11.4   0.0
# 5    aug  sun  22.2   0.0
# 6    aug  mon  24.1   0.0
# 7    aug  mon   8.0   0.0
# 8    sep  tue  13.1   0.0
# 9    sep  sat  22.8   0.0
# 10   sep  sat  17.8   0.0
# 11   sep  sat  19.3   0.0
# 12   aug  fri  17.0   0.0
# 13   sep  mon  21.3   0.0
# 14   sep  wed  26.4   0.0
# 15   sep  fri  22.9   0.0
# 16   mar  sat  15.1   0.0
# 17   oct  mon  16.7   0.0
# 18   mar  wed  15.9   0.0
# 19   apr  sat   9.3   0.0

# %%
#Print only the even numbers of rows of the dataframe 'df'.
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv',index_col=0)
df_2 = df.iloc[2::2]#Type your code here for indexing the dataframe
print(df_2.head(20))
# Out:
#    Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# X
# 7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.0
# 8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.0
# 8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.0
# 8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.0
# 7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.0
# 6  5   aug  fri  63.5   70.8  665.3   0.8  17.0  72   6.7   0.0   0.0
# 6  5   sep  wed  92.9  133.3  699.6   9.2  26.4  21   4.5   0.0   0.0
# 5  5   mar  sat  91.7   35.8   80.8   7.8  15.1  27   5.4   0.0   0.0
# 6  4   mar  wed  89.2   27.9   70.8   6.3  15.9  35   4.0   0.0   0.0
# 6  4   sep  tue  91.0  129.5  692.6   7.0  18.3  40   2.7   0.0   0.0
# 7  4   jun  sun  94.3   96.3  200.0  56.1  21.0  44   4.5   0.0   0.0
# 7  4   aug  sat  93.5  139.4  594.2  20.3  23.7  32   5.8   0.0   0.0
# ...

# %%
df_2 = df.iloc[2][[0,1,2]]
df_2
# Out:
# X          7
# Y          4
# month    oct
# Name: 2, dtype: object

# %%
df.loc[[2],["Y","temp"]]
# Out:
#     Y  temp
# X
# 2   2  13.9
# 2   2  12.3
# 2   2  11.5
# 2   2   5.5
# 2   2  18.8
# .. ..   ...
# 2   5  33.1
# 2   4  30.6
# 2   4  29.2
# 2   4  25.9
# 2   4  21.9
#
# [73 rows x 2 columns]

# %%
sales[sales["Sales"]>30000].head()
# Out:
#                  Market  No_of_Orders    Profit     Sales
# Region
# Western Africa   Africa           251 -12901.51  78476.06
# Southern Africa  Africa            85  11768.58  51319.50
# North Africa     Africa           182  21643.08  86698.89
# Eastern Africa   Africa           110   8013.04  44182.60
# Central Africa   Africa           103  15606.30  61689.99

# %% [markdown]
# ##### Display the LATAM and Eruopean countries with sales > 250000

# %%
sales[ (sales["Market"].isin(["LATAM" , "Europeran"]) )& (sales["Sales"]>25000)]
# Out:
#                 Market  No_of_Orders    Profit      Sales
# Region
# South America    LATAM           496  12377.59  210710.49
# Central America  LATAM           930  74679.54  461670.28
# Caribbean        LATAM           288  13529.59  116333.05

# %% [markdown]
# #### Print all the columns and the rows where 'area' is greater than 0, 'wind' is greater than 1 and the 'temp' is greater than 15.

# %%
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
df_2 = df[ (df["area"]>0) & ( df["wind"]>1 ) & (df["temp"]>15) ] #Type your code here.
print(df_2.head(20))
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 138  9  9   jul  tue  85.8   48.3  313.4   3.9  18.0  42   2.7   0.0  0.36
# 139  1  4   sep  tue  91.0  129.5  692.6   7.0  21.7  38   2.2   0.0  0.43
# 140  2  5   sep  mon  90.9  126.5  686.5   7.0  21.9  39   1.8   0.0  0.47
# 141  1  2   aug  wed  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0  0.55
# 142  8  6   aug  fri  90.1  108.0  529.8  12.5  21.2  51   8.9   0.0  0.61
# 143  1  2   jul  sat  90.0   51.3  296.3   8.7  16.6  53   5.4   0.0  0.71
# 144  2  5   aug  wed  95.5   99.9  513.3  13.2  23.8  32   5.4   0.0  0.77
# 145  6  5   aug  thu  95.2  131.7  578.8  10.4  27.4  22   4.0   0.0  0.90
# 147  8  3   sep  tue  84.4   73.4  671.9   3.2  24.2  28   3.6   0.0  0.96
# 148  2  2   aug  tue  94.8  108.3  647.1  17.0  17.4  43   6.7   0.0  1.07
# 149  8  6   sep  thu  93.7   80.9  685.2  17.9  23.7  25   4.5   0.0  1.12
# ...

# %% [markdown]
# ### Data Transformation or formatting

# %%
sales.Sales = sales.Sales.floordiv(1000)
sales.head()
# Out:
#                  Market  No_of_Orders    Profit  Sales
# Region
# Western Africa   Africa           251 -12901.51   78.0
# Southern Africa  Africa            85  11768.58   51.0
# North Africa     Africa           182  21643.08   86.0
# Eastern Africa   Africa           110   8013.04   44.0
# Central Africa   Africa           103  15606.30   61.0

# %%
sales.rename(columns={'Sales': 'Sales in Thousands'}, inplace=True)
sales.head()
# Out:
#                  Market  No_of_Orders    Profit  Sales in Thousands
# Region
# Western Africa   Africa           251 -12901.51                78.0
# Southern Africa  Africa            85  11768.58                51.0
# North Africa     Africa           182  21643.08                86.0
# Eastern Africa   Africa           110   8013.04                44.0
# Central Africa   Africa           103  15606.30                61.0

# %%
sales['Profit']
# Out:
# Region
# Western Africa      -12901.51
# Southern Africa      11768.58
# North Africa         21643.08
# Eastern Africa        8013.04
# Central Africa       15606.30
# Western Asia        -16766.90
# Southern Asia        67998.76
# Southeastern Asia    20948.84
# Oceania              54734.02
# Eastern Asia         72805.10
# Central Asia         -2649.76
# Western Europe       82091.27
# Southern Europe      18911.49
# Northern Europe      43237.44
# Eastern Europe       25050.69
# South America        12377.59
# Central America      74679.54
# Caribbean            13529.59
# Western US           44303.65
# Southern US          19991.83
# Eastern US           47462.04
# Central US           33697.43
# Canada                7246.62
# Name: Profit, dtype: float64

# %%
total_sum = sales.Profit.sum()
sales['Profit % of Total'] = sales.Profit.apply(lambda x: x/total_sum*100)

sales.head()
# Out:
#                  Market  No_of_Orders    Profit  Sales in Thousands  \
# Region
# Western Africa   Africa           251 -12901.51                78.0
# Southern Africa  Africa            85  11768.58                51.0
# North Africa     Africa           182  21643.08                86.0
# Eastern Africa   Africa           110   8013.04                44.0
# Central Africa   Africa           103  15606.30                61.0
#
#                  Profit % of Total
# Region
# Western Africa           -1.943646
# Southern Africa           1.772967
# North Africa              3.260587
# Eastern Africa            1.207185
# Central Africa            2.351130

# %%
# Replace  negative values with NAN

sales.loc[sales['Profit']<0,:] = np.nan
sales.head()
# Out:
#                  Market  No_of_Orders    Profit  Sales in Thousands  \
# Region
# Western Africa   Africa         251.0       NaN                78.0
# Southern Africa  Africa          85.0  11768.58                51.0
# North Africa     Africa         182.0  21643.08                86.0
# Eastern Africa      NaN           NaN       NaN                 NaN
# Central Africa   Africa         103.0  15606.30                61.0
#
#                  Profit % of Total
# Region
# Western Africa           -1.943646
# Southern Africa           1.772967
# North Africa              3.260587
# Eastern Africa                 NaN
# Central Africa            2.351130

# %%
data = pd.read_csv('weatherdata.csv')
data.head()
data.Location.unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
data.shape
# Out:
# (142193, 9)

# %%
data.info
# Out:
# <bound method DataFrame.info of               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed
# 0            NaN           W           44.0
# ...
